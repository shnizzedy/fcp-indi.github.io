# %% [markdown]
# # End-to-end walkthrough
#
# This walkthrough is intended to orient a new user to the Configurable Pipeline for the Analysis of Connectomes (C-PAC). This guide is not a complete reference for all of the options available in C-PAC (for all documented options, consult [Running C-PAC](http://fcp-indi.github.io/docs/user/running.html)); rather, this guide is a step-by-step tutorial for familiarizing oneself with the software.
#
# #### About the format of this guide
#
# This guide is presented in a [Jupyter notebook](https://jupyter.org/) running [bash_kernel](https://pypi.org/project/bash_kernel/). If you install Jupyter and bash_kernel on your own machine, you can [download this notebook](https://github.com/shnizzedy/fcp-indi.github.com/blob/source/docs/user/_sources/end-to-end-walkthrough.ipynb) and run the cells interactively. The outputs below the code cells are the actual outputs of the code in those cells.
#
# ## Contents
# 1. [Configuration](#Configuration)
#   1. [General configuration](#General-configuration)
#   1. [Anatomical configuration](#Anatomical-configuration)
#   1. [Functional configuration](#Functional-configuration)
#   1. [Derivatives configuration](#Derivatives-configuration)
# 1. [Local requirements](#Local-requirements)
#   1. [Software and environment requirements](#Software-and-environment-requirements)
#   1. [Data requirements](#Data-requirements)
# 1. [Running C-PAC](#Running-C-PAC)

# %% [markdown]
# ## Configuration
#
# Configuring a pipeline for ananylzing connectomes is so central to C-PAC that that step of the process is the source of the project's name. Before we run C-PAC, we need to define what we want C-PAC to run.
#
# An [interactive <span title="graphical user interface">GUI</span>](https://fcp-indi.github.io/C-PAC_GUI/versions/latest/browser/#/) is available to browse and download the default pipeline configuration as a <span title="Yet Another Markup Language">YAML</span> file. You can also duplicate the default pipeline, edit, and download your custom configuration file. We'll walk through the default configuration here.

# %% [markdown]
# ### General configuration
# Immediately upon navigating to the [<span title="graphical user interface">GUI</span>](https://fcp-indi.github.io/C-PAC_GUI/versions/latest/browser/#/), you should see a section titled "Pipelines" which should contain a card titled "Default" with a subtitle corresponding to the latest C-PAC release (1.6.0 in this screenshot).
#
# ![C-PAC GUI screenshot: Pipelines: Default: C-PAC 1.6.0](_images/pipelines-default.png)
#
# In addition to the title and subtitle, the card shows which sections (anatomical, functional, derivatives) are included in that particular configuration. The controls at the bottom are duplicate, delete, and edit. (The "delete" control is not included on the default pipeline.) Clicking the "Edit" control navigates into that configuration, the first tab of which is "General".
#
# ![C-PAC GUI screenshot: Pipelines: Default: General](_images/default-general.png)
#
# To the right of each option in the GUI is a question mark in a circle. Clicking one of these question marks will open a hovering box containing a brief description of the option and show that option as configured highlighted in the YAML generated by the GUI.

# %% [markdown]
# ### Anatomical configuration
#
# The second tab in the GUI is "Anatomical", which contans options for
#
# * Initial Preprocessing
# * Skull stripping
# * Registration
# * Tissue Segmentation

# %% [markdown]
# ### Functional configuration
#
# The third tab in the GUI is "Functional", which has an on-off toggle and contains options for
#
# * Initial Preprocessing
# * Slice Timing Correction
# * Functional to Anatomical Registration
# * Functional to Template Registration
# * Functional to EPI Registration
# * Distortion Correction
# * ICA AROMA
# * Nuisance Regression
# * Median Angle Correction
# * Smoothing / Z-Scoring

# %% [markdown]
# ### Derivatives configuration
#
# The fourth and final tab in the GUI is "Derivatives" which contains options for
#
# * Time Series Extraction
# * Seed-based Correlation
# * ALFF / f-ALFF
# * Network Centrality
# * Voxel-Mirrored Homotopic Connectivity (VMHC)
# * Regional Homogeneity
# * PyPEER

# %% [markdown]
# ## Local requirements
# ### Software and environment requirements
#
# #### Singularity
#
# ##### Install Singularity
# Singularity has an [Installation user guide](https://sylabs.io/guides/3.0/user-guide/installation.html). Once you (think you) have Singularity installed, you can check by running `singularity --version` in a terminal.

# %%
singularity --version
# Out:
# singularity version 3.5.1

# %% [markdown]
# ##### Pull C-PAC Singularity container

# %%
singularity pull shub://FCP-INDI/C-PAC
# Out:
# INFO:    Use image from cache

# %% [markdown]
# ### Data requirements

# %% [markdown]
# ## Running C-PAC

# %%
mkdir -p $HOME/CPAC-data/anat/outputs
mkdir -p $HOME/CPAC-data/anat/tmp

# %%
singularity run \
  -B $HOME/CPAC-data/anat/outputs:/outputs \
  -B $HOME/CPAC-data/anat/tmp:/scratch \
  C-PAC_latest.sif \
  s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU \
  /outputs participant \
  --pipeline_file configs/BasicAnatomical.yml \
  --participant_ndx 1
# Out:
# Skipping bids-validator for S3 datasets...
#
# #### Running C-PAC
# Number of participants to run in parallel: 1
# Input directory: s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU
# Output directory: /outputs/output
# Working directory: ./cpac_runs/default/output
# Crash directory: /outputs/crash
# Log directory: /outputs/log
# Remove working directory: False
# Available memory: 6.0 (GB)
# Available threads: 1
# Number of threads for ANTs: 1
# Connecting to AWS: fcp-indi anonymously...
# gathering files from S3 bucket (s3.Bucket(name='fcp-indi')) for data/Projects/ADHD200/RawDataBIDS/NYU
#  sub-0010098 ses-1 is missing an func
#  sub-0010027 ses-1 is missing an func
#  sub-0010016 ses-1 is missing an func
#  sub-0010105 ses-1 is missing an func
#  sub-0010055 ses-1 is missing an func
#  sub-0010127 ses-1 is missing an func
# Processing data for participant 1 (sub-0010090)
# Starting participant level processing
# Run called with config file /outputs/cpac_pipeline_config_2020-01-09T15-03-03Z.yml
# /code/CPAC/pipeline/cpac_runner.py:259: UserWarning: We recommend that the working directory full path should have less then 70 characters. Long paths might not work in your operational system.
#   warnings.warn("We recommend that the working directory full path "
# /code/CPAC/pipeline/cpac_runner.py:262: UserWarning: Current working directory: /home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output
#   warnings.warn("Current working directory: %s" % c.workingDirectory)
# 200109-15:03:08,131 nipype.workflow INFO:
#
#
#     C-PAC version: 1.6.0
#
#     Setting maximum number of cores per participant to 1
#     Setting number of participants at once to 1
#     Setting OMP_NUM_THREADS to 1
#     Setting MKL_NUM_THREADS to 1
#     Setting ANTS/ITK thread usage to 1
#     Maximum potential number of cores that might be used during this run: 1
#
#
# 200109-15:03:08,820 nipype.workflow INFO:
#
#
# Pipeline building completed.
#
#
# 200109-15:03:09,346 nipype.workflow INFO:
#
#
# Strategy forks:
# - basic-anatomical
#
#
# 200109-15:03:09,550 nipype.workflow INFO:
# 	 Workflow resting_preproc_sub-0010090_ses-1 settings: ['check', 'execution', 'logging', 'monitoring']
# 200109-15:03:09,604 nipype.workflow INFO:
# 	 Running serially.
# 200109-15:03:09,606 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_gather_0/check_for_s3".
# 200109-15:03:09,619 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" - collecting precomputed outputs
# 200109-15:03:09,619 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" found cached.
# 200109-15:03:09,630 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_deoblique".
# 200109-15:03:09,646 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" - collecting precomputed outputs
# 200109-15:03:09,647 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" found cached.
# 200109-15:03:09,659 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_reorient".
# 200109-15:03:09,678 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" - collecting precomputed outputs
# 200109-15:03:09,679 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" found cached.
# 200109-15:03:09,691 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_3" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_3".
# 200109-15:03:09,717 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_3" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:10,163 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_3".
# 200109-15:03:10,174 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.skull_edge" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/skull_edge".
# 200109-15:03:10,194 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.skull_edge" - collecting precomputed outputs
# 200109-15:03:10,195 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.skull_edge" found cached.
# 200109-15:03:10,206 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip_args".
# 200109-15:03:10,229 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" - collecting precomputed outputs
# 200109-15:03:10,229 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" found cached.
# 200109-15:03:10,243 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_o" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/resample_o".
# 200109-15:03:10,272 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_o" - collecting precomputed outputs
# 200109-15:03:10,273 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_o" found cached.
# 200109-15:03:10,286 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip".
# 200109-15:03:10,343 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" - collecting precomputed outputs
# 200109-15:03:10,344 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" found cached.
# 200109-15:03:10,376 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_brain_mask".
# 200109-15:03:10,419 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" - collecting precomputed outputs
# 200109-15:03:10,419 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" found cached.
# 200109-15:03:10,434 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip_orig_vol".
# 200109-15:03:10,470 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" - collecting precomputed outputs
# 200109-15:03:10,470 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" found cached.
# 200109-15:03:10,487 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_1" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_1".
# 200109-15:03:10,517 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_1" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:10,880 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_1".
# 200109-15:03:10,892 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/resample_u".
# 200109-15:03:10,926 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" - collecting precomputed outputs
# 200109-15:03:10,926 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" found cached.
# 200109-15:03:10,942 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_a" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/montage_a".
# 200109-15:03:10,984 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_a" found cached.
# 200109-15:03:10,986 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_4" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_4".
# 200109-15:03:11,3 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.sinker_0_4".
# 200109-15:03:11,34 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_4" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:11,273 nipype.interface INFO:
# 	 sub: /outputs/output/pipeline_basic-anatomical/sub-0010090_ses-1/qc___skullstrip_vis_a/_sources/_montage_a0/skull_vis_a.png -> /outputs/output/pipeline_basic-anatomical/sub-0010090_ses-1/qc/skullstrip_vis_a/_sources/_montage_a0/skull_vis_a.png
# 200109-15:03:11,395 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_4".
# 200109-15:03:11,409 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_s" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/montage_s".
# 200109-15:03:11,441 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_s" found cached.
# 200109-15:03:11,443 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_5" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_5".
# 200109-15:03:11,457 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.sinker_0_5".
# 200109-15:03:11,483 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_5" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:11,798 nipype.interface INFO:
# 	 sub: /outputs/output/pipeline_basic-anatomical/sub-0010090_ses-1/qc___skullstrip_vis_s/_sources/_montage_s0/skull_vis_s.png -> /outputs/output/pipeline_basic-anatomical/sub-0010090_ses-1/qc/skullstrip_vis_s/_sources/_montage_s0/skull_vis_s.png
# 200109-15:03:11,912 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_5".
# 200109-15:03:11,922 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.create_symlinks_paths_0" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/create_symlinks_paths_0".
# 200109-15:03:11,958 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.create_symlinks_paths_0".
# 200109-15:03:11,971 nipype.workflow INFO:
# 	 [Node] Running "create_symlinks_paths_0" ("nipype.interfaces.utility.base.Merge")
# 200109-15:03:12,332 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.create_symlinks_paths_0".
# 200109-15:03:12,343 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.create_symlinks_0" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/create_symlinks_0".
# 200109-15:03:12,356 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.create_symlinks_0".
# 200109-15:03:12,368 nipype.workflow INFO:
# 	 [Node] Running "create_symlinks_0" ("CPAC.utils.interfaces.function.Function")
# 200109-15:03:12,743 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.create_symlinks_0".
# 200109-15:03:12,978 nipype.workflow INFO:
#
#
#     End of subject workflow resting_preproc_sub-0010090_ses-1
#
#     CPAC run complete:
#
#         Pipeline configuration: basic-anatomical
#         Subject workflow: resting_preproc_sub-0010090_ses-1
#         Elapsed run time (minutes): 0.0807852665583
#         Timing information saved in /outputs/log/cpac_individual_timing_basic-anatomical.csv
#         System time of start:      2020-01-09 15:03:09
#         System time of completion: 2020-01-09 15:03:12

# %%
mkdir -p $HOME/CPAC-data/reg/outputs
mkdir -p $HOME/CPAC-data/reg/tmp

# %%
singularity run \
  -B $HOME/CPAC-data/reg/outputs:/outputs \
  -B $HOME/CPAC-data/reg/tmp:/scratch \
  C-PAC_latest.sif \
  s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU \
  /outputs participant \
  --pipeline_file configs/BasicAnatomical+Registration.yml \
  --participant_ndx 1
# Out:
# Skipping bids-validator for S3 datasets...
#
# #### Running C-PAC
# Number of participants to run in parallel: 1
# Input directory: s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU
# Output directory: /outputs/output
# Working directory: ./cpac_runs/default/output
# Crash directory: /outputs/crash
# Log directory: /outputs/log
# Remove working directory: False
# Available memory: 6.0 (GB)
# Available threads: 1
# Number of threads for ANTs: 1
# Connecting to AWS: fcp-indi anonymously...
# gathering files from S3 bucket (s3.Bucket(name='fcp-indi')) for data/Projects/ADHD200/RawDataBIDS/NYU
#  sub-0010098 ses-1 is missing an func
#  sub-0010027 ses-1 is missing an func
#  sub-0010016 ses-1 is missing an func
#  sub-0010105 ses-1 is missing an func
#  sub-0010055 ses-1 is missing an func
#  sub-0010127 ses-1 is missing an func
# Processing data for participant 1 (sub-0010090)
# Starting participant level processing
# Run called with config file /outputs/cpac_pipeline_config_2020-01-09T15-03-17Z.yml
# /code/CPAC/pipeline/cpac_runner.py:259: UserWarning: We recommend that the working directory full path should have less then 70 characters. Long paths might not work in your operational system.
#   warnings.warn("We recommend that the working directory full path "
# /code/CPAC/pipeline/cpac_runner.py:262: UserWarning: Current working directory: /home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output
#   warnings.warn("Current working directory: %s" % c.workingDirectory)
# 200109-15:03:22,305 nipype.workflow INFO:
#
#
#     C-PAC version: 1.6.0
#
#     Setting maximum number of cores per participant to 1
#     Setting number of participants at once to 1
#     Setting OMP_NUM_THREADS to 1
#     Setting MKL_NUM_THREADS to 1
#     Setting ANTS/ITK thread usage to 1
#     Maximum potential number of cores that might be used during this run: 1
#
#
# 200109-15:03:23,582 nipype.workflow INFO:
#
#
# Pipeline building completed.
#
#
# 200109-15:03:24,209 nipype.workflow INFO:
#
#
# Strategy forks:
# - basic-anatomical-registration
#
#
# 200109-15:03:24,451 nipype.workflow INFO:
# 	 Workflow resting_preproc_sub-0010090_ses-1 settings: ['check', 'execution', 'logging', 'monitoring']
# 200109-15:03:24,547 nipype.workflow INFO:
# 	 Running serially.
# 200109-15:03:24,549 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip_args".
# 200109-15:03:24,564 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" - collecting precomputed outputs
# 200109-15:03:24,564 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" found cached.
# 200109-15:03:24,577 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.resampled_template_brain_for_anat" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/resampled_template_brain_for_anat".
# 200109-15:03:24,590 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.resampled_template_brain_for_anat" - collecting precomputed outputs
# 200109-15:03:24,590 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.resampled_template_brain_for_anat" found cached.
# 200109-15:03:24,600 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_gather_0/check_for_s3".
# 200109-15:03:24,612 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" - collecting precomputed outputs
# 200109-15:03:24,612 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" found cached.
# 200109-15:03:24,628 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_deoblique".
# 200109-15:03:24,650 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" - collecting precomputed outputs
# 200109-15:03:24,651 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" found cached.
# 200109-15:03:24,673 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_reorient".
# 200109-15:03:24,701 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" - collecting precomputed outputs
# 200109-15:03:24,702 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" found cached.
# 200109-15:03:24,718 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip".
# 200109-15:03:24,770 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" - collecting precomputed outputs
# 200109-15:03:24,770 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" found cached.
# 200109-15:03:24,800 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_brain_mask".
# 200109-15:03:24,843 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" - collecting precomputed outputs
# 200109-15:03:24,843 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" found cached.
# 200109-15:03:24,864 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip_orig_vol".
# 200109-15:03:24,904 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" - collecting precomputed outputs
# 200109-15:03:24,904 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" found cached.
# 200109-15:03:24,923 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.calc_ants_warp" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_mni_ants_register_0/calc_ants_warp".
# 200109-15:03:25,85 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.calc_ants_warp" - collecting precomputed outputs
# 200109-15:03:25,85 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.calc_ants_warp" found cached.
# 200109-15:03:25,208 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_affine" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_mni_ants_register_0/select_forward_affine".
# 200109-15:03:25,305 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_affine" - collecting precomputed outputs
# 200109-15:03:25,305 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_affine" found cached.
# 200109-15:03:25,317 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_7" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_7".
# 200109-15:03:25,352 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_7" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:25,723 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_7".
# 200109-15:03:25,735 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_warp" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_mni_ants_register_0/select_forward_warp".
# 200109-15:03:25,862 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_warp" - collecting precomputed outputs
# 200109-15:03:25,862 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_warp" found cached.
# 200109-15:03:25,873 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_5" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_5".
# 200109-15:03:25,903 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.sinker_0_5".
# 200109-15:03:25,925 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_5" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:26,654 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_5".
# 200109-15:03:26,666 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_initial" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_mni_ants_register_0/select_forward_initial".
# 200109-15:03:26,793 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_initial" - collecting precomputed outputs
# 200109-15:03:26,794 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_initial" found cached.
# 200109-15:03:26,802 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_8" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_8".
# 200109-15:03:26,824 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_8" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:27,158 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_8".
# 200109-15:03:27,167 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_rigid" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_mni_ants_register_0/select_forward_rigid".
# 200109-15:03:27,265 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_rigid" - collecting precomputed outputs
# 200109-15:03:27,265 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_forward_rigid" found cached.
# 200109-15:03:27,276 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_9" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_9".
# 200109-15:03:27,311 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_9" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:27,651 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_9".
# 200109-15:03:27,663 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_2" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_2".
# 200109-15:03:27,697 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_2" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:28,57 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_2".
# 200109-15:03:28,66 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/resample_u".
# 200109-15:03:28,83 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" - collecting precomputed outputs
# 200109-15:03:28,84 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" found cached.
# 200109-15:03:28,102 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.skull_edge" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/skull_edge".
# 200109-15:03:28,126 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.skull_edge" - collecting precomputed outputs
# 200109-15:03:28,126 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.skull_edge" found cached.
# 200109-15:03:28,139 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_o" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/resample_o".
# 200109-15:03:28,162 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_o" - collecting precomputed outputs
# 200109-15:03:28,163 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_o" found cached.
# 200109-15:03:28,179 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_s" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/montage_s".
# 200109-15:03:28,206 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_s" found cached.
# 200109-15:03:28,208 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_12" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_12".
# 200109-15:03:28,245 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_12" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:28,484 nipype.interface INFO:
# 	 sub: /outputs/output/pipeline_basic-anatomical-registration/sub-0010090_ses-1/qc___skullstrip_vis_s/_sources/_montage_s0/skull_vis_s.png -> /outputs/output/pipeline_basic-anatomical-registration/sub-0010090_ses-1/qc/skullstrip_vis_s/_sources/_montage_s0/skull_vis_s.png
# 200109-15:03:28,581 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_12".
# 200109-15:03:28,592 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_a" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/montage_a".
# 200109-15:03:28,621 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_a" found cached.
# 200109-15:03:28,624 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_11" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_11".
# 200109-15:03:28,666 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_11" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:28,905 nipype.interface INFO:
# 	 sub: /outputs/output/pipeline_basic-anatomical-registration/sub-0010090_ses-1/qc___skullstrip_vis_a/_sources/_montage_a0/skull_vis_a.png -> /outputs/output/pipeline_basic-anatomical-registration/sub-0010090_ses-1/qc/skullstrip_vis_a/_sources/_montage_a0/skull_vis_a.png
# 200109-15:03:29,29 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_11".
# 200109-15:03:29,39 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_6" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_6".
# 200109-15:03:29,169 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_6" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:29,519 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_6".
# 200109-15:03:29,530 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_4" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_4".
# 200109-15:03:29,541 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.sinker_0_4".
# 200109-15:03:29,558 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_4" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:29,937 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_4".
# 200109-15:03:29,948 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_inverse_warp" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_mni_ants_register_0/select_inverse_warp".
# 200109-15:03:30,60 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_inverse_warp" - collecting precomputed outputs
# 200109-15:03:30,61 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.select_inverse_warp" found cached.
# 200109-15:03:30,70 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_10" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_10".
# 200109-15:03:30,94 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_10" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-15:03:30,566 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_10".
# 200109-15:03:30,575 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.create_symlinks_paths_0" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/create_symlinks_paths_0".
# 200109-15:03:30,641 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.create_symlinks_paths_0".
# 200109-15:03:30,658 nipype.workflow INFO:
# 	 [Node] Running "create_symlinks_paths_0" ("nipype.interfaces.utility.base.Merge")
# 200109-15:03:31,14 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.create_symlinks_paths_0".
# 200109-15:03:31,25 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.create_symlinks_0" in "/home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/create_symlinks_0".
# 200109-15:03:31,38 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.create_symlinks_0".
# 200109-15:03:31,46 nipype.workflow INFO:
# 	 [Node] Running "create_symlinks_0" ("CPAC.utils.interfaces.function.Function")
# 200109-15:03:31,381 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.create_symlinks_0".
# 200109-15:03:31,895 nipype.workflow INFO:
#
#
#     End of subject workflow resting_preproc_sub-0010090_ses-1
#
#     CPAC run complete:
#
#         Pipeline configuration: basic-anatomical-registration
#         Subject workflow: resting_preproc_sub-0010090_ses-1
#         Elapsed run time (minutes): 0.159839649995
#         Timing information saved in /outputs/log/cpac_individual_timing_basic-anatomical-registration.csv
#         System time of start:      2020-01-09 15:03:24
#         System time of completion: 2020-01-09 15:03:31

# %%
mkdir -p $HOME/CPAC-data/func/outputs
mkdir -p $HOME/CPAC-data/func/tmp

# %%
singularity run \
  -B $HOME/CPAC-data/func/outputs:/outputs \
  -B $HOME/CPAC-data/func/tmp:/scratch \
  C-PAC_latest.sif \
  s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU \
  /outputs participant \
  --pipeline_file configs/BasicAnatomical+Registration+Functional.yml \
  --participant_ndx 1
# Out:
# Skipping bids-validator for S3 datasets...
#
# #### Running C-PAC
# Number of participants to run in parallel: 1
# Input directory: s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU
# Output directory: /outputs/output
# Working directory: ./cpac_runs/default/output
# Crash directory: /outputs/crash
# Log directory: /outputs/log
# Remove working directory: False
# Available memory: 6.0 (GB)
# Available threads: 1
# Number of threads for ANTs: 1
# Connecting to AWS: fcp-indi anonymously...
# gathering files from S3 bucket (s3.Bucket(name='fcp-indi')) for data/Projects/ADHD200/RawDataBIDS/NYU
#  sub-0010098 ses-1 is missing an func
#  sub-0010027 ses-1 is missing an func
#  sub-0010016 ses-1 is missing an func
#  sub-0010105 ses-1 is missing an func
#  sub-0010055 ses-1 is missing an func
#  sub-0010127 ses-1 is missing an func
# Processing data for participant 1 (sub-0010090)
# Starting participant level processing
# Run called with config file /outputs/cpac_pipeline_config_2020-01-09T15-03-36Z.yml
# /code/CPAC/pipeline/cpac_runner.py:259: UserWarning: We recommend that the working directory full path should have less then 70 characters. Long paths might not work in your operational system.
#   warnings.warn("We recommend that the working directory full path "
# /code/CPAC/pipeline/cpac_runner.py:262: UserWarning: Current working directory: /home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output
#   warnings.warn("Current working directory: %s" % c.workingDirectory)
# 200109-15:03:42,216 nipype.workflow INFO:
#
#
#     C-PAC version: 1.6.0
#
#     Setting maximum number of cores per participant to 1
#     Setting number of participants at once to 1
#     Setting OMP_NUM_THREADS to 1
#     Setting MKL_NUM_THREADS to 1
#     Setting ANTS/ITK thread usage to 1
#     Maximum potential number of cores that might be used during this run: 1
#
#
# Traceback (most recent call last):
#   File "/code/run.py", line 588, in <module>
#     test_config = 1 if args.analysis_level == "test_config" else 0
#   File "/code/CPAC/pipeline/cpac_runner.py", line 344, in run
#     p_name, plugin, plugin_args, test_config)
#   File "/code/CPAC/pipeline/cpac_pipeline.py", line 2181, in prep_workflow
#     'anatomical_wm_mask': (seg_preproc_template_based, 'outputspec.wm_mask')
#   File "/code/CPAC/utils/strategy.py", line 50, in update_resource_pool
#     'replacing with %s ' % (key, value)
# Exception: Key anatomical_csf_mask already exists in resource pool, replacing with (resting_preproc_sub-0010090_ses-1.seg_preproc_epi_template_0, 'outputspec.csf_mask')
# : 1

# %%
mkdir -p $HOME/CPAC-data/default/outputs
mkdir -p $HOME/CPAC-data/default/tmp

# %%
singularity run \
  -B $HOME/CPAC-data/outputs:/outputs \
  -B $HOME/CPAC-data/tmp:/scratch \
  C-PAC_latest.sif \
  s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU \
  /outputs participant \
  --pipeline_file configs/Default.yml \
  --participant_ndx 1
# Out:
# Skipping bids-validator for S3 datasets...
#
# #### Running C-PAC
# Number of participants to run in parallel: 1
# Input directory: s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU
# Output directory: /outputs/output
# Working directory: ./cpac_runs/default/output
# Crash directory: /outputs/crash
# Log directory: /outputs/log
# Remove working directory: False
# Available memory: 6.0 (GB)
# Available threads: 1
# Number of threads for ANTs: 1
# Connecting to AWS: fcp-indi anonymously...
# gathering files from S3 bucket (s3.Bucket(name='fcp-indi')) for data/Projects/ADHD200/RawDataBIDS/NYU
#  sub-0010098 ses-1 is missing an func
#  sub-0010027 ses-1 is missing an func
#  sub-0010016 ses-1 is missing an func
#  sub-0010105 ses-1 is missing an func
#  sub-0010055 ses-1 is missing an func
#  sub-0010127 ses-1 is missing an func
# Processing data for participant 1 (sub-0010090)
# Starting participant level processing
# Run called with config file /outputs/cpac_pipeline_config_2020-01-09T15-05-41Z.yml
# /code/CPAC/pipeline/cpac_runner.py:259: UserWarning: We recommend that the working directory full path should have less then 70 characters. Long paths might not work in your operational system.
#   warnings.warn("We recommend that the working directory full path "
# /code/CPAC/pipeline/cpac_runner.py:262: UserWarning: Current working directory: /home/jclucas/fcp-indi.github.com/docs/user/_sources/cpac_runs/default/output
#   warnings.warn("Current working directory: %s" % c.workingDirectory)
# 200109-15:05:46,92 nipype.workflow INFO:
#
#
#     C-PAC version: 1.6.0
#
#     Setting maximum number of cores per participant to 1
#     Setting number of participants at once to 1
#     Setting OMP_NUM_THREADS to 1
#     Setting MKL_NUM_THREADS to 1
#     Setting ANTS/ITK thread usage to 1
#     Maximum potential number of cores that might be used during this run: 1
#
#
# Traceback (most recent call last):
#   File "/code/run.py", line 588, in <module>
#     test_config = 1 if args.analysis_level == "test_config" else 0
#   File "/code/CPAC/pipeline/cpac_runner.py", line 344, in run
#     p_name, plugin, plugin_args, test_config)
#   File "/code/CPAC/pipeline/cpac_pipeline.py", line 2181, in prep_workflow
#     'anatomical_wm_mask': (seg_preproc_template_based, 'outputspec.wm_mask')
#   File "/code/CPAC/utils/strategy.py", line 50, in update_resource_pool
#     'replacing with %s ' % (key, value)
# Exception: Key anatomical_csf_mask already exists in resource pool, replacing with (resting_preproc_sub-0010090_ses-1.seg_preproc_epi_template_0, 'outputspec.csf_mask')
# : 1
