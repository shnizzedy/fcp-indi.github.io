# %% [markdown]
# # End-to-end walkthrough
#
# This walkthrough is intended to orient a new user to the Configurable Pipeline for the Analysis of Connectomes (C-PAC). This guide is not a complete reference for all of the options available in C-PAC (for all documented options, consult [Running C-PAC](http://fcp-indi.github.io/docs/user/running.html)); rather, this guide is a step-by-step tutorial for familiarizing oneself with the software.
#
# #### About the format of this guide
#
# This guide is presented in a [Jupyter notebook](https://jupyter.org/) running [bash_kernel](https://pypi.org/project/bash_kernel/). If you install Jupyter and bash_kernel on your own machine, you can download and run the cells in this notebook interactively. The outputs below the code cells are the outputs of the code in those cells.
#
# ## Contents
# 1. [Configuration](#Configuration)
#   1. [General configuration](#General-configuration)
#   1. [Anatomical configuration](#Anatomical-configuration)
#   1. [Functional configuration](#Functional-configuration)
#   1. [Derivatives configuration](#Derivatives-configuration)
# 1. [Local requirements](#Local-requirements)
#   1. [Software and environment requirements](#Software-and-environment-requirements)
#   1. [Data requirements](#Data-requirements)
# 1. [Running C-PAC](#Running-C-PAC)

# %% [markdown]
# ## Configuration
#
# Configuring a pipeline for ananylzing connectomes is so central to C-PAC that that step of the process is the source of the project's name. Before we run C-PAC, we need to define what we want C-PAC to run.
#
# An [interactive <span title="graphical user interface">GUI</span>](https://fcp-indi.github.io/C-PAC_GUI/versions/latest/browser/#/) is available to browse and download the default pipeline configuration as a <span title="Yet Another Markup Language">YAML</span> file. You can also duplicate the default pipeline, edit, and download your custom configuration file. We'll walk through the default configuration here.

# %% [markdown]
# ### General configuration
# Immediately upon navigating to the [<span title="graphical user interface">GUI</span>](https://fcp-indi.github.io/C-PAC_GUI/versions/latest/browser/#/), you should see a section titled "Pipelines" which should contain a card titled "Default" with a subtitle corresponding to the latest C-PAC release (1.6.0 in this screenshot).
# ![C-PAC GUI screenshot: Pipelines: Default: C-PAC 1.6.0](_images/pipelines-default.png)
# In addition to the title and subtitle, the card shows which sections (anatomical, functional, derivatives) are included in that particular configuration. The controls at the bottom are duplicate, delete, and edit. (The "delete" control is not included on the default pipeline.) Clicking the "Edit" control navigates into that configuration, the first tab of which is "General".
# ![C-PAC GUI screenshot: Pipelines: Default: General](_images/default-general.png)
# To the right of each option in the GUI is a question mark in a circle. Clicking one of these question marks will open a hovering box containing a brief description of the option and show that option as configured highlighted in the YAML generated by the GUI.

# %% [markdown]
# ### Anatomical configuration
# The second tab in the GUI is "Anatomical", which contans options for
# * Initial Preprocessing
# * Skull stripping
# * Registration
# * Tissue Segmentation

# %% [markdown]
# ### Functional configuration
# The third tab in the GUI is "Functional", which has an on-off toggle and contains options for
# * Initial Preprocessing
# * Slice Timing Correction
# * Functional to Anatomical Registration
# * Functional to Template Registration
# * Functional to EPI Registration
# * Distortion Correction
# * ICA AROMA
# * Nuisance Regression
# * Median Angle Correction
# * Smoothing / Z-Scoring

# %% [markdown]
# ### Derivatives configuration
# The fourth and final tab in the GUI is "Derivatives" which contains options for
# * Time Series Extraction
# * Seed-based Correlation
# * ALFF / f-ALFF
# * Network Centrality
# * Voxel-Mirrored Homotopic Connectivity (VMHC)
# * Regional Homogeneity
# * PyPEER

# %% [markdown]
# ## Local requirements
# ### Software and environment requirements
#
# #### Singularity
#
# ##### Install Singularity
# Singularity has an [Installation user guide](https://sylabs.io/guides/3.0/user-guide/installation.html). Once you (think you) have Singularity installed, you can check by running `singularity --version` in a terminal.

# %%
singularity --version
# Out:
# singularity version 3.5.1

# %% [markdown]
# ##### Pull C-PAC Singularity container

# %%
singularity pull shub://FCP-INDI/C-PAC
# Out:
# FATAL:   Image file already exists: "C-PAC_latest.sif" - will not overwrite
# : 255

# %% [markdown]
# ### Data requirements

# %% [markdown]
# ## Running C-PAC

# %%
mkdir -p $HOME/CPAC-data/outputs
mkdir -p $HOME/CPAC-data/tmp

# %%
singularity run \
  -B $HOME/CPAC-data/outputs:/outputs \
  -B $HOME/CPAC-data/tmp:/scratch \
  C-PAC_latest.sif \
  s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU \
  /outputs participant \
  --pipeline_file configs/BasicAnatomical.yml \
  --participant_ndx 1
# Out:
# Skipping bids-validator for S3 datasets...
#
# #### Running C-PAC
# Number of participants to run in parallel: 1
# Input directory: s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU
# Output directory: /outputs/output
# Working directory: ./cpac_runs/default/output
# Crash directory: /outputs/crash
# Log directory: /outputs/log
# Remove working directory: False
# Available memory: 6.0 (GB)
# Available threads: 1
# Number of threads for ANTs: 1
# Connecting to AWS: fcp-indi anonymously...
# gathering files from S3 bucket (s3.Bucket(name='fcp-indi')) for data/Projects/ADHD200/RawDataBIDS/NYU
#  sub-0010098 ses-1 is missing an func
#  sub-0010027 ses-1 is missing an func
#  sub-0010016 ses-1 is missing an func
#  sub-0010105 ses-1 is missing an func
#  sub-0010055 ses-1 is missing an func
#  sub-0010127 ses-1 is missing an func
# Processing data for participant 1 (sub-0010090)
# Starting participant level processing
# Run called with config file /outputs/cpac_pipeline_config_2020-01-09T13-06-40Z.yml
# 200109-13:06:45,120 nipype.workflow INFO:
#
#
#     C-PAC version: 1.6.0
#
#     Setting maximum number of cores per participant to 1
#     Setting number of participants at once to 1
#     Setting OMP_NUM_THREADS to 1
#     Setting MKL_NUM_THREADS to 1
#     Setting ANTS/ITK thread usage to 1
#     Maximum potential number of cores that might be used during this run: 1
#
#
# 200109-13:06:45,750 nipype.workflow INFO:
#
#
# Pipeline building completed.
#
#
# 200109-13:06:46,227 nipype.workflow INFO:
#
#
# Strategy forks:
# - basic-anatomical
#
#
# 200109-13:06:46,411 nipype.workflow INFO:
# 	 Workflow resting_preproc_sub-0010090_ses-1 settings: ['check', 'execution', 'logging', 'monitoring']
# 200109-13:06:46,449 nipype.workflow INFO:
# 	 Running serially.
# 200109-13:06:46,450 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_gather_0/check_for_s3".
# 200109-13:06:46,459 nipype.workflow INFO:
# 	 [Node] Running "check_for_s3" ("CPAC.utils.interfaces.function.Function")
# Connecting to AWS: fcp-indi anonymously...
# Attempting to download from AWS S3: s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU/sub-0010090/ses-1/anat/sub-0010090_ses-1_run-1_T1w.nii.gz
# 200109-13:06:48,715 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3".
# 200109-13:06:48,723 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_deoblique".
# 200109-13:06:48,767 nipype.workflow INFO:
# 	 [Node] Running "anat_deoblique" ("nipype.interfaces.afni.utils.Refit"), a CommandLine Interface with command:
# 3drefit -deoblique /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_deoblique/sub-0010090_ses-1_run-1_T1w.nii.gz
# 200109-13:06:49,98 nipype.interface INFO:
# 	 stderr 2020-01-09T13:06:49.098329:++ 3drefit: AFNI version=AFNI_16.3.08 (Nov  4 2016) [64-bit]
# 200109-13:06:49,99 nipype.interface INFO:
# 	 stderr 2020-01-09T13:06:49.098329:++ Authored by: RW Cox
# 200109-13:06:49,128 nipype.interface INFO:
# 	 stderr 2020-01-09T13:06:49.128854:++ Processing AFNI dataset /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_deoblique/sub-0010090_ses-1_run-1_T1w.nii.gz
# 200109-13:06:49,137 nipype.interface INFO:
# 	 stderr 2020-01-09T13:06:49.137139: + loading and re-writing dataset /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_deoblique/sub-0010090_ses-1_run-1_T1w.nii.gz (/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_deoblique/sub-0010090_ses-1_run-1_T1w.nii.gz in NIFTI storage)
# 200109-13:06:51,525 nipype.interface INFO:
# 	 stderr 2020-01-09T13:06:51.525850:++ 3drefit processed 1 datasets
# 200109-13:06:51,760 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique".
# 200109-13:06:51,767 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_reorient".
# 200109-13:06:51,783 nipype.workflow INFO:
# 	 [Node] Running "anat_reorient" ("nipype.interfaces.afni.utils.Resample"), a CommandLine Interface with command:
# 3dresample -orient RPI -prefix sub-0010090_ses-1_run-1_T1w_resample.nii.gz -inset /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_reorient/sub-0010090_ses-1_run-1_T1w.nii.gz
# 200109-13:06:55,979 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient".
# 200109-13:06:56,11 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.skull_edge" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/skull_edge".
# 200109-13:06:56,59 nipype.workflow INFO:
# 	 [Node] Running "skull_edge" ("CPAC.utils.interfaces.function.Function")
# 200109-13:07:01,499 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.skull_edge".
# 200109-13:07:01,506 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_o" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/resample_o".
# 200109-13:07:01,518 nipype.workflow INFO:
# 	 [Node] Running "resample_o" ("CPAC.utils.interfaces.function.Function")
# 200109-13:07:03,467 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_o".
# 200109-13:07:03,474 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_3" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_3".
# 200109-13:07:03,493 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_3" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-13:07:03,880 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_3".
# 200109-13:07:03,889 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip_args".
# 200109-13:07:03,904 nipype.workflow INFO:
# 	 [Node] Running "anat_skullstrip_args" ("nipype.interfaces.utility.wrappers.Function")
# 200109-13:07:04,256 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args".
# 200109-13:07:04,266 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip".
# 200109-13:07:04,290 nipype.workflow INFO:
# 	 [Node] Running "anat_skullstrip" ("nipype.interfaces.afni.preprocess.SkullStrip"), a CommandLine Interface with command:
# 3dSkullStrip -input /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip/sub-0010090_ses-1_run-1_T1w_resample.nii.gz  -prefix sub-0010090_ses-1_run-1_T1w_resample_skullstrip.nii.gz
# 200109-13:08:59,844 nipype.interface INFO:
# 	 stderr 2020-01-09T13:08:59.843498:The intensity in the output dataset is a modified version
# 200109-13:08:59,854 nipype.interface INFO:
# 	 stderr 2020-01-09T13:08:59.843498:of the intensity in the input volume.
# 200109-13:08:59,854 nipype.interface INFO:
# 	 stderr 2020-01-09T13:08:59.854464:To obtain a masked version of the input with identical values inside
# 200109-13:08:59,854 nipype.interface INFO:
# 	 stderr 2020-01-09T13:08:59.854464:the brain, you can either use 3dSkullStrip's -orig_vol option
# 200109-13:08:59,854 nipype.interface INFO:
# 	 stderr 2020-01-09T13:08:59.854464:or run the following command:
# 200109-13:08:59,855 nipype.interface INFO:
# 	 stderr 2020-01-09T13:08:59.854464:  3dcalc -a /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip/sub-0010090_ses-1_run-1_T1w_resample.nii.gz -b ./sub-0010090_ses-1_run-1_T1w_resample_skullstrip.nii.gz+orig -expr 'a*step(b)' \
# 200109-13:08:59,855 nipype.interface INFO:
# 	 stderr 2020-01-09T13:08:59.854464:         -prefix ./sub-0010090_ses-1_run-1_T1w_resample_skullstrip.nii.gz_orig_vol
# 200109-13:08:59,855 nipype.interface INFO:
# 	 stderr 2020-01-09T13:08:59.854464:to generate a new masked version of the input.
# 200109-13:09:00,342 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip".
# 200109-13:09:00,369 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_brain_mask".
# 200109-13:09:00,398 nipype.workflow INFO:
# 	 [Node] Running "anat_brain_mask" ("nipype.interfaces.afni.utils.Calc"), a CommandLine Interface with command:
# 3dcalc -a /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip/sub-0010090_ses-1_run-1_T1w_resample_skullstrip.nii.gz -expr "step(a)" -prefix sub-0010090_ses-1_run-1_T1w_resample_skullstrip_calc.nii.gz
# 200109-13:09:00,857 nipype.interface INFO:
# 	 stderr 2020-01-09T13:09:00.856662:++ 3dcalc: AFNI version=AFNI_16.3.08 (Nov  4 2016) [64-bit]
# 200109-13:09:00,857 nipype.interface INFO:
# 	 stderr 2020-01-09T13:09:00.856662:++ Authored by: A cast of thousands
# 200109-13:09:02,776 nipype.interface INFO:
# 	 stderr 2020-01-09T13:09:02.776184:++ Output dataset ./sub-0010090_ses-1_run-1_T1w_resample_skullstrip_calc.nii.gz
# 200109-13:09:03,15 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask".
# 200109-13:09:03,33 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip_orig_vol".
# 200109-13:09:03,79 nipype.workflow INFO:
# 	 [Node] Running "anat_skullstrip_orig_vol" ("nipype.interfaces.afni.utils.Calc"), a CommandLine Interface with command:
# 3dcalc -a /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_reorient/sub-0010090_ses-1_run-1_T1w_resample.nii.gz -b /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_brain_mask/sub-0010090_ses-1_run-1_T1w_resample_skullstrip_calc.nii.gz -expr "a*step(b)" -prefix sub-0010090_ses-1_run-1_T1w_resample_calc.nii.gz
# 200109-13:09:03,387 nipype.interface INFO:
# 	 stderr 2020-01-09T13:09:03.387271:++ 3dcalc: AFNI version=AFNI_16.3.08 (Nov  4 2016) [64-bit]
# 200109-13:09:03,388 nipype.interface INFO:
# 	 stderr 2020-01-09T13:09:03.387271:++ Authored by: A cast of thousands
# 200109-13:09:05,438 nipype.interface INFO:
# 	 stderr 2020-01-09T13:09:05.438351:++ Output dataset ./sub-0010090_ses-1_run-1_T1w_resample_calc.nii.gz
# 200109-13:09:05,709 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol".
# 200109-13:09:05,726 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_1" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_1".
# 200109-13:09:05,759 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_1" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-13:09:06,198 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_1".
# 200109-13:09:06,232 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/resample_u".
# 200109-13:09:06,267 nipype.workflow INFO:
# 	 [Node] Running "resample_u" ("CPAC.utils.interfaces.function.Function")
# 200109-13:09:07,317 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u".
# 200109-13:09:07,326 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_s" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/montage_s".
# 200109-13:09:07,407 nipype.workflow INFO:
# 	 [Node] Setting-up "_montage_s0" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/montage_s/mapflow/_montage_s0".
# 200109-13:09:07,427 nipype.workflow INFO:
# 	 [Node] Running "_montage_s0" ("CPAC.utils.interfaces.function.Function")
# 200109-13:09:14,292 nipype.workflow INFO:
# 	 [Node] Finished "_montage_s0".
# 200109-13:09:14,308 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_s".
# 200109-13:09:14,311 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_a" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/montage_a".
# 200109-13:09:14,343 nipype.workflow INFO:
# 	 [Node] Setting-up "_montage_a0" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/montage_a/mapflow/_montage_a0".
# 200109-13:09:14,356 nipype.workflow INFO:
# 	 [Node] Running "_montage_a0" ("CPAC.utils.interfaces.function.Function")
# 200109-13:09:25,665 nipype.workflow INFO:
# 	 [Node] Finished "_montage_a0".
# 200109-13:09:25,685 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.montage_a".
# 200109-13:09:25,687 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_4" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_4".
# 200109-13:09:25,716 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_4" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-13:09:25,970 nipype.interface INFO:
# 	 sub: /outputs/output/pipeline_basic-anatomical/sub-0010090_ses-1/qc___skullstrip_vis_a/_montage_a0/skull_vis_a.png -> /outputs/output/pipeline_basic-anatomical/sub-0010090_ses-1/qc/skullstrip_vis_a/_montage_a0/skull_vis_a.png
# 200109-13:09:26,121 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_4".
# 200109-13:09:26,132 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_5" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_5".
# 200109-13:09:26,159 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_5" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-13:09:26,409 nipype.interface INFO:
# 	 sub: /outputs/output/pipeline_basic-anatomical/sub-0010090_ses-1/qc___skullstrip_vis_s/_montage_s0/skull_vis_s.png -> /outputs/output/pipeline_basic-anatomical/sub-0010090_ses-1/qc/skullstrip_vis_s/_montage_s0/skull_vis_s.png
# 200109-13:09:26,556 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_5".
# 200109-13:09:26,571 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.create_symlinks_paths_0" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/create_symlinks_paths_0".
# 200109-13:09:26,633 nipype.workflow INFO:
# 	 [Node] Running "create_symlinks_paths_0" ("nipype.interfaces.utility.base.Merge")
# 200109-13:09:27,19 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.create_symlinks_paths_0".
# 200109-13:09:27,29 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.create_symlinks_0" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/create_symlinks_0".
# 200109-13:09:27,58 nipype.workflow INFO:
# 	 [Node] Running "create_symlinks_0" ("CPAC.utils.interfaces.function.Function")
# 200109-13:09:27,465 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.create_symlinks_0".
# 200109-13:09:27,759 nipype.workflow INFO:
#
#
#     End of subject workflow resting_preproc_sub-0010090_ses-1
#
#     CPAC run complete:
#
#         Pipeline configuration: basic-anatomical
#         Subject workflow: resting_preproc_sub-0010090_ses-1
#         Elapsed run time (minutes): 2.71066594919
#         Timing information saved in /outputs/log/cpac_individual_timing_basic-anatomical.csv
#         System time of start:      2020-01-09 13:06:46
#         System time of completion: 2020-01-09 13:09:27

# %%
singularity run \
  -B $HOME/CPAC-data/outputs:/outputs \
  -B $HOME/CPAC-data/tmp:/scratch \
  C-PAC_latest.sif \
  s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU \
  /outputs participant \
  --pipeline_file configs/BasicAnatomical+Registration.yml \
  --participant_ndx 1
# Out:
# Skipping bids-validator for S3 datasets...
#
# #### Running C-PAC
# Number of participants to run in parallel: 1
# Input directory: s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU
# Output directory: /outputs/output
# Working directory: ./cpac_runs/default/output
# Crash directory: /outputs/crash
# Log directory: /outputs/log
# Remove working directory: False
# Available memory: 6.0 (GB)
# Available threads: 1
# Number of threads for ANTs: 1
# Connecting to AWS: fcp-indi anonymously...
# gathering files from S3 bucket (s3.Bucket(name='fcp-indi')) for data/Projects/ADHD200/RawDataBIDS/NYU
#  sub-0010098 ses-1 is missing an func
#  sub-0010027 ses-1 is missing an func
#  sub-0010016 ses-1 is missing an func
#  sub-0010105 ses-1 is missing an func
#  sub-0010055 ses-1 is missing an func
#  sub-0010127 ses-1 is missing an func
# Processing data for participant 1 (sub-0010090)
# Starting participant level processing
# Run called with config file /outputs/cpac_pipeline_config_2020-01-09T13-17-05Z.yml
# 200109-13:17:10,868 nipype.workflow INFO:
#
#
#     C-PAC version: 1.6.0
#
#     Setting maximum number of cores per participant to 1
#     Setting number of participants at once to 1
#     Setting OMP_NUM_THREADS to 1
#     Setting MKL_NUM_THREADS to 1
#     Setting ANTS/ITK thread usage to 1
#     Maximum potential number of cores that might be used during this run: 1
#
#
# 200109-13:17:12,379 nipype.workflow INFO:
#
#
# Pipeline building completed.
#
#
# 200109-13:17:13,520 nipype.workflow INFO:
#
#
# Strategy forks:
# - basic-anatomical-registration
#
#
# 200109-13:17:13,813 nipype.workflow INFO:
# 	 Workflow resting_preproc_sub-0010090_ses-1 settings: ['check', 'execution', 'logging', 'monitoring']
# 200109-13:17:13,871 nipype.workflow INFO:
# 	 Running serially.
# 200109-13:17:13,872 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.resampled_template_brain_for_anat" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/resampled_template_brain_for_anat".
# 200109-13:17:13,886 nipype.workflow INFO:
# 	 [Node] Running "resampled_template_brain_for_anat" ("CPAC.utils.interfaces.function.Function")
# 200109-13:17:14,140 nipype.workflow INFO:
# 	 [Node] Setting-up "template_brain_for_anat" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/resampled_template_brain_for_anat/template_brain_for_anat".
# 200109-13:17:14,169 nipype.workflow INFO:
# 	 [Node] Running "template_brain_for_anat" ("nipype.interfaces.afni.utils.Resample"), a CommandLine Interface with command:
# 3dresample -prefix MNI152_T1_2mm_brain_resample.nii.gz -rmode Cu -dxyz 2.000000 2.000000 2.000000 -inset /home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/resampled_template_brain_for_anat/template_brain_for_anat/MNI152_T1_2mm_brain.nii.gz
# 200109-13:17:14,974 nipype.workflow INFO:
# 	 [Node] Finished "template_brain_for_anat".
# 200109-13:17:15,84 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.resampled_template_brain_for_anat".
# 200109-13:17:15,92 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip_args".
# 200109-13:17:15,104 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" - collecting precomputed outputs
# 200109-13:17:15,104 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_args" found cached.
# 200109-13:17:15,115 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_gather_0/check_for_s3".
# 200109-13:17:15,125 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" - collecting precomputed outputs
# 200109-13:17:15,125 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_gather_0.check_for_s3" found cached.
# 200109-13:17:15,138 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_deoblique".
# 200109-13:17:15,158 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" - collecting precomputed outputs
# 200109-13:17:15,158 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_deoblique" found cached.
# 200109-13:17:15,172 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_reorient".
# 200109-13:17:15,194 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" - collecting precomputed outputs
# 200109-13:17:15,195 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_reorient" found cached.
# 200109-13:17:15,212 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_4" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_4".
# 200109-13:17:15,225 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "resting_preproc_sub-0010090_ses-1.sinker_0_4".
# 200109-13:17:15,246 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_4" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-13:17:15,648 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_4".
# 200109-13:17:15,664 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip".
# 200109-13:17:15,696 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" - collecting precomputed outputs
# 200109-13:17:15,696 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip" found cached.
# 200109-13:17:15,716 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_brain_mask".
# 200109-13:17:15,738 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" - collecting precomputed outputs
# 200109-13:17:15,739 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_brain_mask" found cached.
# 200109-13:17:15,750 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_preproc_afni_0/anat_skullstrip_orig_vol".
# 200109-13:17:15,777 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" - collecting precomputed outputs
# 200109-13:17:15,778 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.anat_preproc_afni_0.anat_skullstrip_orig_vol" found cached.
# 200109-13:17:15,799 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/qc_skullstrip_0/montage_skull/resample_u".
# 200109-13:17:15,818 nipype.workflow INFO:
# 	 [Node] Cached "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" - collecting precomputed outputs
# 200109-13:17:15,818 nipype.workflow INFO:
# 	 [Node] "resting_preproc_sub-0010090_ses-1.qc_skullstrip_0.montage_skull.resample_u" found cached.
# 200109-13:17:15,829 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.sinker_0_2" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/sinker_0_2".
# 200109-13:17:15,852 nipype.workflow INFO:
# 	 [Node] Running "sinker_0_2" ("CPAC.utils.interfaces.datasink.DataSink")
# 200109-13:17:16,256 nipype.workflow INFO:
# 	 [Node] Finished "resting_preproc_sub-0010090_ses-1.sinker_0_2".
# 200109-13:17:16,272 nipype.workflow INFO:
# 	 [Node] Setting-up "resting_preproc_sub-0010090_ses-1.anat_mni_ants_register_0.calc_ants_warp" in "/home/jclucas/fcp-indi.github.com/docs/user/cpac_runs/default/output/resting_preproc_sub-0010090_ses-1/anat_mni_ants_register_0/calc_ants_warp".
# 200109-13:17:16,338 nipype.workflow INFO:
# 	 [Node] Running "calc_ants_warp" ("nipype.interfaces.utility.wrappers.Function")

# %%
singularity run \
  -B $HOME/CPAC-data/outputs:/outputs \
  -B $HOME/CPAC-data/tmp:/scratch \
  C-PAC_latest.sif \
  s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU \
  /outputs participant \
  --pipeline_file configs/BasicAnatomical+Registration+Functional.yml \
  --participant_ndx 1

# %%
singularity run \
  -B $HOME/CPAC-data/outputs:/outputs \
  -B $HOME/CPAC-data/tmp:/scratch \
  C-PAC_latest.sif \
  s3://fcp-indi/data/Projects/ADHD200/RawDataBIDS/NYU \
  /outputs participant \
  --pipeline_file configs/Default.yml \
  --participant_ndx 1
